# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# importing the dataset

student_df = pd.read_csv("student_data_HV.csv", index_col=0)
student_df.head()
# Out:
#    Dalc  Fedu  G1  G2  G3  Medu Pstatus  Walc  absences activities  ...  \
# 0     1     4   5   6   6     4       A     1         6         no  ...
# 1     1     1   5   5   6     1       T     1         4         no  ...
# 2     2     1   7   8  10     1       T     3        10         no  ...
# 3     1     2  15  14  15     4       T     1         2        yes  ...
# 4     1     3   6  10  10     3       T     2         4         no  ...
#
#    internet  location  nursery paid romantic  school  schoolsup  sex  \
# 0        no     Urban      yes   no       no      GP        yes    F
# 1       yes     Urban       no   no       no      GP         no    F
# 2       yes     Urban      yes  yes       no      GP        yes    F
# 3       yes     Urban      yes  yes      yes      GP         no    F
# 4        no     Urban      yes  yes       no      GP         no    F
#
#       study_time traveltime
# 0   2 to 5 hours        2.0
# 1   2 to 5 hours        1.0
# 2   2 to 5 hours        1.0
# ...

# %% [markdown]
# ## 1. Basic Descriptive Analysis

# %%
student_df.shape
# Out:
# (395, 29)

# %%
student_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 395 entries, 0 to 394
# Data columns (total 29 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Dalc        395 non-null    int64
#  1   Fedu        395 non-null    int64
#  2   G1          395 non-null    int64
#  3   G2          395 non-null    int64
#  4   G3          395 non-null    int64
#  5   Medu        395 non-null    int64
#  6   Pstatus     395 non-null    object
#  7   Walc        395 non-null    int64
#  8   absences    395 non-null    int64
#  9   activities  395 non-null    object
#  10  age         395 non-null    int64
#  11  failures    395 non-null    int64
#  12  famrel      395 non-null    int64
#  13  famsize     395 non-null    object
#  14  famsup      395 non-null    object
#  15  freetime    395 non-null    int64
#  16  goout       395 non-null    int64
#  17  health      395 non-null    int64
#  18  higher      395 non-null    object
# ...

# %%
student_df.describe()
# Out:
#              Dalc        Fedu          G1          G2          G3        Medu  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     1.481013    2.521519   10.908861   10.713924   10.415190    2.749367
# std      0.890741    1.088201    3.319195    3.761505    4.581443    1.094735
# min      1.000000    0.000000    3.000000    0.000000    0.000000    0.000000
# 25%      1.000000    2.000000    8.000000    9.000000    8.000000    2.000000
# 50%      1.000000    2.000000   11.000000   11.000000   11.000000    3.000000
# 75%      2.000000    3.000000   13.000000   13.000000   14.000000    4.000000
# max      5.000000    4.000000   19.000000   19.000000   20.000000    4.000000
#
#              Walc    absences         age    failures      famrel    freetime  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     2.291139    5.708861   16.696203    0.334177    3.944304    3.235443
# ...

# %% [markdown]
# ## 2: Univariate Analysis:
#
# - If categorical, value_counts/ bar plot
# - If numerical, Histogram

# %% [markdown]
# ## 3: Bi-variate Analysis:
#
# * Scatterplot
# * Variance/ Std Dev

# %% [markdown]
# ## 4: Missing Value Analysis:

# %% [markdown]
# ## 5: Outlier Analysis:
# - Box plots

# %% [markdown]
# ## 6: Correlation Analysis:

# %% [markdown]
# ## 7: Answering Research Questions:

# %% [markdown]
# ### Questions:
# * Relationship between absences and failures
# * Relationship between absences and activities
# * Relationship between age and failures
# * Relationship between famrel and famsize
# * Relationship between absences and famrel
# * Relationship between famrel and famsize
# * Relationship between abscenses and internet
# * Relationship between internet and abscences
#
# ### important performance indicators:
# - failures
# - health
# - freetime
# - study_time
# - absences
